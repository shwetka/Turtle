# %%
# !pip install mobilechelonian

# %% [markdown]
# Привет! Мы начинаем с вами курс програмирования.
# Перед вами много разного непонятного текста, это мы настраиваем необходимую для работы среду.
# (обратите внимание, что если все хорошо настроилось, то теаст будет черным и в нем будут встречаться такие слова:
# Requirement already satisfied:)
# В нашем курсе мы будем писать программы на языке Питон,  в специальном модуле turtle,  который специально разработан для обучения)
#
# Питон (Python)  это язык программирования, очень удобный для обучения, его придумали чуть меньше сорока лет назад.

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
Сверху тоже необходимая для работы настройки. 
Сейчас мы подключим нужный нам модуль turtle

# %%
from mobilechelonian import Turtle
t=Turtle()
# Out:
# Turtle()

# %% [markdown]
# Знакомимся "Черепашка" (turtle). Этот модуль лучше всего подходит для обучения, потому что твоя задача управлять черепашкой, которая стоит в   середине экрана.  Ей можно давать разные команды и она послушно будет их выполнять. Она может оставлять за собой цветной след и рисовать, а может "поднять перо " и просто перемещаться.
# Для начала подключим этот модуль. Для это нам нужно будет написать вот такую волшебную фразу
# ![images%20%281%29.jpg](attachment:images%20%281%29.jpg)

# %% [markdown]
# Раз мы подключили новый модуль, самое время сказать черепашке вперед! Черепашка наша понимает только по английски, поэтому мы называем нашу черепашку t и будем повторять t. перед каждой командой. Дадим черепашке команду пойти на 100 шагов( пикселей) вперед. Пишем t.forward и обязательно в скобочках количество точек, на которые должна пойти черепашка

# %%
t=Turtle()
t.forward(100)
# Out:
# Turtle()

# %% [markdown]
# Посмотри, куда пошла черепашка. Обрати внимание, что она смотрит вправо и идет вправо.
# Черепашка умеет поворачивать направо (right) и налево (left). В скобочках указывается количество градусов. Давай посмотрим, куда повернет черепашка, ели мы попросим ее повернуть направо  на 45 градусов. Давай вспомним, что в полном круге 360 градусов, полукруг это 180 градусов, четверть круга это 90. Смотри:
# ![images%20%281%29.png](attachment:images%20%281%29.png)

# %%
t=Turtle()
t.forward (100)
t.right(45)
# Out:
# Turtle()

# %% [markdown]
# Повернем теперь нашу черепашку на 90 градусов

# %%
t=Turtle()
t.forward (100)
t.right(90)
# Out:
# Turtle()

# %% [markdown]
# Давай подумаем, как нам сделать квадрат. Напиши для черепашки недостающие команды.
# ( У квадрата все стороны равны и все углы равны и равны 90 градусам. ) Черепашка может поварачивать направо или налево.
# ![exterior-angle-square.png](attachment:exterior-angle-square.png)

# %%
t=Turtle()
t.forward (100)
t.right(90)
# Out:
# Turtle()

# %% [markdown]
# У тебя должен получиться квадрат. Вот такой. ![exterior-angle-square.png](attachment:exterior-angle-square.png)

# %% [markdown]
# Поэксперементируй. Дай черепашке поворачивать не направо, а налево. Попробуй сам поверкуться налево на 90 градусов и направо  270 градусов. Есть ли разница? В таком же положении окажется черепашка? Нарисуй квардат несколькими разными способами.

# %%
t=Turtle()
# Out:
# Turtle()

# %% [markdown]
# Теперь пришла пора задачки посложнее. Давай попробуем нарисовать треугольник,  у которого все стороны и все углы равны. Такой треугольник называется равносторонним. внутренние углы в нем будут равны 60 градусам, но черепашке придется поворачивать на 120. На картинкерозовым отмечен угол, на который должна повернуть черепашка.  .. ![exterior-angle-triangle.png](attachment:exterior-angle-triangle.png)

# %%
t=Turtle()

# %% [markdown]
# Подумай, как нарисовать пятиугольник. Посмотри на картинку. На сколько градусов должна повернуть черепашка, чтобы получился правильный пятиугольник. ![exterior-angle-pentagon.png](attachment:exterior-angle-pentagon.png)

# %%
t=Turtle()
t.forward (100)
t.right(90) *

# %% [markdown]
# Внимание! Тут конец первого урока!

# %% [markdown]
# Урок 2
# Ты заметил сколько раз ты писал одни и те же команды? Много? Для того, чтобы не писать много раз одно и тоже в Питоне( Да и в любом другом языке программирования) были придуманы специальные заклинания( конструкции),  которые позволяют повторить несколько раз одно и то же.
# В Питоне один из циклов устроем так
# for i in range (5):
# Буквально- пока i находится в диапазоне от 0 до 5,  или- проще- повтори 5 раз.
# следующие строчки- это то, что программа будет повторять, надо отобвинуть от края кнопочкой TAB

# %%
t=Turtle()
for i in range (5):
    t.forward (10)
# Out:
# Turtle()

# %% [markdown]
# Черепашка пройдет 50 шагов  (5 раз п 10 шагов). А теперь давай вернемся немного назад и снова нарисуем квадрат, но уже по новому, используя цикл. Цикл нужно повторить только раз, сколько... Вставь пропущенные цифры и команды в программу ниже.

# %%
t=Turtle()
for i in range ( ):
    t.forward (100)
            (90)

# %% [markdown]
# А теперь напиши  сам программу, и нарисуй треугольник, пятиугольник, шестиугольник и десятиугольник. Маленькая подсказка-
# Для того, посчитать угол, на который должна повернуть черепашка, необходимо 360 разделить на количество углов в нашей фигуре.
# Квадрат - 360 / 4 = 90 (/- это знак деления в программировании)
# Треугольник 360/3 =120
# Обрати внимание, что в скобках можно писать или число, или выражение( например 360/4), тогда программа выполнит деление сама.

# %%
t=Turtle()

# %% [markdown]
# Получилось? А теперь подумай, как нарисовать круг. ( Это тоже многоугольник с очень большим количесвом углов)

# %%
t=Turtle()

# %%
Внимание! Тут конец второго урока!

# %% [markdown]
# Урок 3
# Получилось?
# Наверное тебе надоело, что черепашка оставляет за собой только церную линию. Сейчас я покажу тебе как она умеет менять цвет.
# Для этого нужно написать
# color(цвет)
# Цвет нужно писать на английском
# ![basic-color-circles-printable-1.jpg](attachment:basic-color-circles-printable-1.jpg)

# %%
t=Turtle()
t.color="red"
t.forward (30)
t.color="blue"
t.forward (40)
# Out:
# Turtle()

# %% [markdown]
# Наша черепашка умеет двигаться так, чтобы не оставлять за собой след. Для этого ей надо дать команду
# up()
# В скобках ничего писать не надо!
# когда нужно, чтобы черепаха снова  оставляла след, дайте ей команду
# down()
# Внизу пример, как нарисовать прерывистую линию

# %%
t=Turtle()
t.color="red"
t.forward (30)
t.penup()
t.forward(30)
t.pendown()
t.color="blue"
t.forward (40)
# Out:
# Turtle()

# %% [markdown]
# А теперь пришла пора проверить, как хорошо ты научился управлять черепашкой.
# Нарисуй дом, с дверью, окнами и крышей. ( Дом состоит из прямоугольников, квадратов, треугольников). Обязатено используй циклы. Вот пример дома для вдохновения. ![images%20%282%29.png](attachment:images%20%282%29.png)

# %%
t=Turtle()
